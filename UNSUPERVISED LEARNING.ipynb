# %% [markdown]
# # UNSUPERVISED LEARNING

# %% [markdown]
# * UNSUPERVISED LEARNING ,also known as unsupervised machine learning,uses machine learning algorithms to analyze and cluster unlabeled datasets.
# * These algorithms discover hidden patterns or data groupings without the need for human intervention .

# %% [markdown]
# Unsupervised learning models are utilized for three main tasks :
#   -  1. Clustering
#   -  2. Association
#   -  3. Dimensionality reduction

# %% [markdown]
# # **1 ) CLUSTERING**

# %% [markdown]
# * CLUSTERING is the data mining technique which groups unlabeled data based on thier similarities or differences.
# * CLUSTERING algorithm are used to process raw,unclassified data objects into groups represented by structures or patterns in the information.
# * CLUSTERING algorithm can be categorized into a few types ,specifically
#  -  1. exclusive
#  -  2. overlapping
#  -  3. hierarchical
#  -  4. probabilistic

# %% [markdown]
# # **(1) EXCLUSIVE CLUSTERING**

# %% [markdown]
# EXCLUSIVE CLUSTERING
# * EXCLUSIVE CLUSTERING is a form of grouping that stimulates a data point can exist in only one cluster.
# * This can also be reffered to as "hard" clustering.
# * THE K-MEANS CLUSTERING ALGORITHM IS AN EXAMPLE OF EXCLUSIVE CLUSTERING.

# %% [markdown]
# example

# %% [markdown]
# **K-means Clustering**
#
# * K-means clustering is a common example of an exclusive clustering method where data points are assigned into K groups,
# * where K represents the number of clusters based on the distance from each group's centroid.
# * The data points closest to a given centroid will be clustered under the same category.
# * A larger K value will be indicative of smaller groupings whereas a smaller K value will have larger groupings.
# * K-means clustering is commonly used in market segmentation, document clustering, image segmentation, and image compression,.

# %% [markdown]
# * **K-means clustering** is a popular unsupervised machine learning algorithm used for partitioning a dataset into K distinct, non-overlapping subsets (clusters).
#   The goal of the K-means algorithm is to find groups in the data, with the number of groups represented by the variable K.
#   The algorithm works iteratively to assign each data point to one of K clusters based on certain features.

# %% [markdown]
# **PROCESS OF K-MEANS CLUSTERING**
#
#
# * 1)**1initialization**:
#    - Choose the number of clusters (K) you want to identify. Randomly initialize the centroids of the K clusters.
#
# * 2)**Assignment**
#    - Assign each data point to the nearest centroid, forming K clusters
#
#    - Finding the best cluster centroids in K-means clustering involves selecting the initialization that results in the most optimal clustering solution.
#    - Since K-means is sensitive to the initial placement of centrolds, running the algorithm with different initiallzations and choosing
#      the one with the lowest cost (sum of squared distances from each point to its assigned centroid) is a common approach
#    - Choose Best Solution:
#      Select the solution with the lowest inertia or cost Inertia is available as the inertia_ attribute in scikit-learn's KMeans.
#
# * 3)**Update Centroids**:
#    - Calculate the mean of the data points in each cluster. Move the centroid of each cluster to the calculated mean.
#
# * 4)**Repeat**:
#    - Repeat steps 2 and 3 until convergence is reached (centroids no longer change significantly).
#
# * 5)**Result**
#    - The algorithm converges to a solution where the data points are grouped into K clusters, and each cluster is represented by its centroid.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **(2) OVERLAPPING CLUSTERING**

# %% [markdown]
# OVERLAPPING CLUSTERING
#
# * IT differ from exclusive clustering in that it allows data points to belong to multiple clusters with separate degrees of membership. "Soft" or fuzzy k-means clustering is an example of overlapping clustering.
#
# * where the boundaries between clusters are not well-defined. Overlapping clusters can be a challenging problem because most traditional clustering algorithms, such as k-means, assume that clusters are distinct and non-overlapping
#
# * example:-
#     - Fuzzy Clustering Gaussian Mixture Models (GMMs) Spectral Clustering Affinity Propagation

# %% [markdown]
# # **(3) HIERARCHICAL CLUSTERING**

# %% [markdown]
# * HIERARCHICAL CLUSTERING also known as hirerchical cluster analysis(HCA) ,is an unsupervised clustering algorithm tht can be categorized in to 2 WAYS
#   * AGGLOMERATIVE
#   * DIVISIVE

# %% [markdown]
# **1 ) AGGLOMERATIVE**
#
# * Agglomerative clustering is considered a "bottoms-up approach" Its data points are isolated as separate groupings initially,
# * and then they are merged together Iteratively on the basis of similarity until one cluster has been achieved.
# * Four different methods are commonly used to measure similarity

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * In hierarchical clustering, **LINKAGES** are methods used to calculate the distance between clusters at each step of the agglomerative clustering process.
#
# * Hierarchical clustering builds a tree-like structure of clusters, where the leaves of the tree represent individual data poirits, and the branches represent the merging of clusters.
#   - 1) Single (or minimum) linkage:
#     - This method is defined by the minimum distance between two points in each cluster
#
#   - 2) Average linkage.
#    -  This method is defined by the mean distance between two points in each cluster
#
#   - 3) Complete (or maximum) linkage:
#     - This method is defined by the maximum distance between two ponts in each cluster
#
#   - 4) Ward's method
#     - itminimizes the sum of squared differences within all clusters. When merging two clusters, it chooses the pair that, when merged results in the smallest increase in the overall sum of squared differences

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **DENDROGRAM**
#
# * A dendrogram is a tree-structured graph used in heat maps to visualize the result of a hierarchical clustering calculation.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2 )DIVISIVE CLUSTERING**
#
# * Divisive clusteringcan be defined sa the opposite of agglomerative clustering.
# * It takes a "Top Down"approach. this case, a single data cluster is divided based on the differences between data points.
# * Divisive clustering is not commonly used, but it is still worth noting in the context of hierarchical clustering.
# * These clustering processes are usually visualized using a dendrogram, a tree-like diagram that documents the merging or splitting of data points at each iteration.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **(4)PROBABILISTIC CLUSTERING**

# %% [markdown]
# * PROBABILISTIC CLUSTERING  model is an unsupervised techiques that help us to solve density estimation or "soft" clustering problems.
# * in probabilistic clustering data points are clusterred based on the likelihood that they belog to a paricular distribution
#
# * eg:-
#   - GUASSIAN MIXTURE MODEL:
#     - GUASSIAN MIXTURE MODEL are classified as mixture model,which means that they are made up of an unspecified number of probability distribution functions

# %% [markdown]
# # **2 ) ASSOCIATION RULE**

# %% [markdown]
# * An association tule is a tule-based method for finding relationships between variables as a given dataset.
# * These methods are frequently used for market basket analysis, allowing companies to better understand relationships between different products

# %% [markdown]
# # **3 )Dimensionality Reduction**

# %% [markdown]
# * When more data generally yields more accurate  results, it can also impact the performance of machine learning algorithms (e.g. overfitting) and it can also make it difficult to visualize datasets.
# * Dimensionality reduction is a technique used when the number of features, or dimensions, in a given dataset is too high.
# * It reduces the number of data inputs to a manageable size while also preserving the integrity of the dataset as much as possible.
# * It is commonly used in the preprocessing data stage

# %% [markdown]
# **Feature selection & Feature extraction**

# %% [markdown]
# **FEATURE EXTRACTION**
#
# * Feature extraction involves transforming raw data into a new representation that captures the essential characteristics or features of the original data.
# * This transformation can involve techniques like dimensionality reduction, where high-dimensional data is transformed into a lower-dimensional space while preserving important information.
#
# * purpose
#   - : Feature extraction is used to simplify data and make it more manageable for analysis or to improve the performance of machine learning algorithms by reducing the complexity of the input space.
# * eg :-
#   - Principal Component Analysis (PCA) is a common technique used for feature extraction.

# %% [markdown]
# **FEATURE SELECTION**
#
# * Feature selection involves choosing a subset of the original features (variables) that are most relevant to the problem at hand.
# * The selected features are used for building predictive models or for analysis, while irrelevant or redundant features are discarded.
# * purpose :-
#   - The goal of feature selection is to improve model performance, reduce overfitting, and enhance interpretability by focusing only on the most informative features.

# %% [markdown]
# **PRINCIPAL COMPONENT ANALYSIS(PCA)**
#
# * it is a type of dimensionality reduction algorithm which is used to compress dataset through feature extraction
#
# * primary goal of pca is to transform high dimentional data into a new coordinate system,capturing most important information while discarding less important information

# %% [markdown]
# **steps of pca**
#
# * stp1 :- standardization of data:-
#   - The first step is to often to standardize the data by substracting the mean and dividing by the standard diviation for each feature.
#   - This ensures that all features have the same scale.
#
# * stp2 :- Covariance Matrix Calculation:-
#   - Calculate the covariance matrix for the standardized data. The covariance matrix provides information about the relationships between different features
#
# * stp3 : Eigenvalue and Eigenvector Computation
# :-
#   - Compute the eigenvalues and corresponding eigenvectors of the covariance matrix.
#   -  Eigenvectors represent the directions of maximum variance, and eigenvalues indicate the magnitude of the variance in those directions
#
# * stp4 :- Selection of Principal Components
# :-
#   - Sort the elgenvalues in descending order and choose the top k eigenvectors (where k is the desired number of dimensions for the new feature space). These top eigenvectors are the principal components.
#
# * stp5 :- Projection
# :-
#   - Form a new matrix using the selected eigenvectors as columns. This matrix can be used to transform the original data into the reduced dimensional space by multiplying it with the standardized data

# %% [markdown]
# ![WhatsApp Image 2024-09-11 at 14.33.12_410ccc22.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-09-11 at 14.34.29_6b95513b.jpg](data:image/jpeg;base64,...)
